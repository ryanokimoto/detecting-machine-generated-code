# %%
# !pip install --upgrade transformers==4.45.0 huggingface_hub
# %pip install torch numpy pandas scikit-learn evaluate
# !pip install "transformers==4.57.1" "accelerate>=1.1.1" "torch>=2.4.0" "datasets>=3.0.0" "peft>=0.13.0"

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
# Out:
# Collecting transformers==4.45.0
#   Using cached transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: huggingface_hub in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (0.36.0)
# Collecting huggingface_hub
#   Using cached huggingface_hub-1.1.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (2025.11.3)
# Requirement already satisfied: requests in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (2.32.5)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.0)
#   Using cached tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.45.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface_hub) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.45.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.45.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.45.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.45.0) (2025.11.12)
# Using cached transformers-4.45.0-py3-none-any.whl (9.9 MB)
# Using cached tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:╺━━━━━━━━━━━━━━━━━━━ 1/2 [transformers]
#       Successfully uninstalled transformers-4.57.1━━━━━━━━━━━━ 1/2 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers] [transformers]
# Successfully installed tokenizers-0.20.3 transformers-4.45.0
# Requirement already satisfied: torch in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (2.9.1)
# Requirement already satisfied: numpy in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (2.3.4)
# Requirement already satisfied: pandas in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: evaluate in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (0.4.6)
# Requirement already satisfied: filelock in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: datasets>=2.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (4.4.1)
# Requirement already satisfied: dill in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: requests>=2.19.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from evaluate) (25.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: anyio in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: certifi in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformers==4.57.1
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: accelerate>=1.1.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (1.11.0)
# Requirement already satisfied: torch>=2.4.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (2.9.1)
# Requirement already satisfied: datasets>=3.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (4.4.1)
# Requirement already satisfied: peft>=0.13.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (0.18.0)
# Requirement already satisfied: filelock in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (2025.11.3)
# Requirement already satisfied: requests in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==4.57.1)
#   Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from transformers==4.57.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (1.2.0)
# Requirement already satisfied: psutil in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from accelerate>=1.1.1) (7.1.3)
# Requirement already satisfied: setuptools in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (3.5)
# Requirement already satisfied: jinja2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from torch>=2.4.0) (3.5.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (0.4.0)
# Requirement already satisfied: pandas in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (0.28.1)
# Requirement already satisfied: xxhash in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from datasets>=3.0.0) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (3.13.2)
# Requirement already satisfied: anyio in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=3.0.0) (4.11.0)
# Requirement already satisfied: certifi in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=3.0.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=3.0.0) (1.0.9)
# Requirement already satisfied: idna in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=3.0.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=3.0.0) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=3.0.0) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.57.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from requests->transformers==4.57.1) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4.0) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from anyio->httpx<1.0.0->datasets>=3.0.0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from jinja2->torch>=2.4.0) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas->datasets>=3.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas->datasets>=3.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from pandas->datasets>=3.0.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/achang93/miniconda3/envs/semeval/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0) (1.17.0)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.45.0
#     Uninstalling transformers-4.45.0:╺━━━━━━━━━━━━━━━━━━━ 1/2 [transformers]
#       Successfully uninstalled transformers-4.45.0━━━━━━━━━━━━ 1/2 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers] [transformers]
# Successfully installed tokenizers-0.22.1 transformers-4.57.1

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
import torch
import numpy as np
import pandas as pd
from datasets import load_dataset, Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback,
    DataCollatorWithPadding
)
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report
import argparse
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We suggest using a single class, it will make refinement easier.
#
# In your implementation, feel free to update the training procedure, change model and do whatever feels right

# %%
class GraphCodeBERTTrainer:
    def __init__(self, max_length=512, model_name="microsoft/graphcodebert-base"):
        self.max_length = max_length
        self.model_name = model_name
        self.tokenizer = None
        self.model = None
        self.num_labels = None
        
    def load_and_prepare_data(self):
        
        try:
            df = pd.read_parquet('./dataset/train.parquet')
            
            print(f"Dataset columns: {df.columns.tolist()}")
            print(f"Sample data:\n{df.head()}")
            
            if 'code' not in df.columns or 'label' not in df.columns:
                raise ValueError("Dataset must contain 'code' and 'label' columns")
            
            df = df.dropna(subset=['code', 'label'])
            
            df['label'] = df['label'].astype(int)
            self.num_labels = df['label'].nunique()
            
            print(f"Number of unique labels: {self.num_labels}")
            print(f"Label range: {df['label'].min()} to {df['label'].max()}")
            print(f"Label distribution:\n{df['label'].value_counts().sort_index()}")

            val_df = pd.read_parquet('./dataset/validation.parquet')
            
            print(f"Train samples: {len(df)}, Validation samples: {len(val_df)}")
            
            return df, val_df
            
        except Exception as e:
            print(f"Error loading dataset: {e}")
            raise
    
    def initialize_model_and_tokenizer(self):
        print(f"Initializing {self.model_name} model and tokenizer...")
        
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(
            self.model_name,
            num_labels=self.num_labels,
            problem_type="single_label_classification",
            trust_remote_code=True
        ).to('cuda' if torch.cuda.is_available() else 'cpu')
        
        print(f"Model initialized with {self.num_labels} labels")
    
    def tokenize_function(self, examples):
        return self.tokenizer(
            examples['code'],
            truncation=True,
            padding=True,
            max_length=self.max_length,
            return_tensors="pt"
        )
    
    def prepare_datasets(self, train_df, val_df):
        print("Preparing datasets for training...")
        
        train_dataset = Dataset.from_pandas(train_df[['code', 'label']])
        val_dataset = Dataset.from_pandas(val_df[['code', 'label']])
        
        train_dataset = train_dataset.map(
            self.tokenize_function,
            batched=True,
            remove_columns=['code']
        )
        val_dataset = val_dataset.map(
            self.tokenize_function,
            batched=True,
            remove_columns=['code']
        )
        
        train_dataset = train_dataset.rename_column('label', 'labels')
        val_dataset = val_dataset.rename_column('label', 'labels')
        
        return train_dataset, val_dataset
    
    def compute_metrics(self, eval_pred):
        predictions, labels = eval_pred
        predictions = np.argmax(predictions, axis=1)
        
        accuracy = accuracy_score(labels, predictions)
        precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average='weighted')
        
        return {
            'accuracy': accuracy,
            'f1': f1,
            'precision': precision,
            'recall': recall
        }
    
    def train(self, train_dataset, val_dataset, output_dir="./results", num_epochs=3, batch_size=16, learning_rate=2e-5):
        print("Starting training...")
        print(self.model)
        print(self.model.device)
        training_args = TrainingArguments(
            output_dir=output_dir,
            num_train_epochs=num_epochs,
            per_device_train_batch_size=batch_size,
            per_device_eval_batch_size=batch_size,
            # warmup_steps=500,
            weight_decay=0.01,
            logging_dir='./logs',
            logging_steps=5,
            eval_strategy="steps",
            eval_steps=500,
            save_strategy="steps",
            save_steps=500,
            load_best_model_at_end=True,
            metric_for_best_model="f1",
            greater_is_better=True,
            remove_unused_columns=False,
            learning_rate=learning_rate,
            lr_scheduler_type="linear",
            save_total_limit=2,
            report_to=[],
        )
        
        data_collator = DataCollatorWithPadding(tokenizer=self.tokenizer)
        
        trainer = Trainer(
            model=self.model,
            args=training_args,
            train_dataset=train_dataset,
            eval_dataset=val_dataset,
            tokenizer=self.tokenizer,
            data_collator=data_collator,
            compute_metrics=self.compute_metrics,
            callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
        )
        print(f"Start training")
        trainer.train()
        
        trainer.save_model()
        self.tokenizer.save_pretrained(output_dir)
        
        print(f"Training completed. Model saved to {output_dir}")
        
        return trainer
    
    def evaluate_model(self, trainer, val_dataset):
        print("Evaluating model...")
        
        predictions = trainer.predict(val_dataset)
        y_pred = np.argmax(predictions.predictions, axis=1)
        y_true = predictions.label_ids
        
        print("Classification Report:")
        print(classification_report(y_true, y_pred))
        
        return predictions
    
    def run_full_pipeline(self, output_dir="./results", num_epochs=3, batch_size=16, learning_rate=2e-5):
        try:
            train_df, val_df = self.load_and_prepare_data()
            
            self.initialize_model_and_tokenizer()
            
            train_dataset, val_dataset = self.prepare_datasets(train_df, val_df)
            
            trainer = self.train(
                train_dataset, val_dataset, 
                output_dir=output_dir,
                num_epochs=num_epochs,
                batch_size=batch_size,
                learning_rate=learning_rate
            )
            
            self.evaluate_model(trainer, val_dataset)
            
            print("Pipeline completed successfully!")
            return trainer
            
        except Exception as e:
            print(f"Error in pipeline: {e}")
            raise

# %%
OUTPUT_DIR = "taskA-model"

trainer_obj = GraphCodeBERTTrainer(
    max_length=256,
    model_name="microsoft/graphcodebert-base" 
)

t = trainer_obj.run_full_pipeline(
    output_dir=OUTPUT_DIR,
    num_epochs=10,
    batch_size=16,
    learning_rate=2e-5
)
# Out:
# Dataset columns: ['code', 'generator', 'label', 'language']
# Sample data:
#                                                 code  \
# 0  (a, b, c, d) = [int(x) for x in input().split(...
# 1  valid version for the language; all others can...
# 2  python\ndef min_cards_to_flip(s):\n    vowels ...
# 3  T = int(input())\nfor t in range(T):\n\tcolor ...
# 4  for i in range(int(input())):\n\tinput()\n\ta ...
#
#                         generator  label language
td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Model saved to taskA-model
# Evaluating model...
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     47695
#            1       0.99      0.99      0.99     52305
#
#     accuracy                           0.99    100000
#    macro avg       0.99      0.99      0.99    100000
# weighted avg       0.99      0.99      0.99    100000
#
# Pipeline completed successfully!

# %%
import torch
import logging
from itertools import chain
from datasets import load_dataset
from tqdm import tqdm


@torch.no_grad()
def predict_with_trainer(trainer_obj, parquet_path, output_path, max_length=512, batch_size=16, device=None):
    """
    Uses trainer_obj.model and trainer_obj.tokenizer to run streaming inference
    over a parquet file with columns ['ID','code'] and writes 'ID,prediction' CSV.
    """
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"

    # Pull model & tokenizer from your trainer object
    model = trainer_obj.model
    tokenizer = trainer_obj.tokenizer if hasattr(trainer_obj, "tokenizer") else trainer_obj.args._setup_devices and None
    if tokenizer is None and hasattr(trainer_obj, "tokenizer"):
        tokenizer = trainer_obj.tokenizer
    if tokenizer is None:
        raise ValueError("trainer_obj must have a tokenizer (e.g., provided when creating the Trainer).")
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model.to(device)
    model.eval()

    # Stream parquet (no RAM blowup)
    ds = load_dataset("parquet", data_files=parquet_path, split="train", streaming=True)

    # Validate schema and re-chain the first row back into the stream
    it = iter(ds)
    first = next(it)
    if not {"ID", "code"}.issubset(first.keys()):
        raise ValueError("Parquet file must contain 'ID' and 'code' columns")
    stream = chain([first], it)

    def batcher(iterator, bs):
        buf = []
        for ex in iterator:
            buf.append(ex)
            if len(buf) == bs:
                yield buf
                buf = []
        if buf:
            yield buf

    with open(output_path, "w") as f:
        f.write("ID,prediction\n")

        for batch in tqdm(batcher(stream, batch_size), desc="Predicting"):
            codes = [row["code"] for row in batch]
            ids   = [row["ID"] for row in batch]

            enc = tokenizer(
                codes,
                truncation=True,
                padding=True,
                max_length=max_length,
                return_tensors="pt",
            )
            input_ids = enc["input_ids"].to(device)
            attention_mask = enc["attention_mask"].to(device)

            logits = model(input_ids=input_ids, attention_mask=attention_mask).logits
            pred_labels = logits.argmax(dim=-1).cpu().tolist()

            for ex_id, pred in zip(ids, pred_labels):
                f.write(f"{ex_id},{pred}\n")

    print(f"Predictions saved to {output_path}")

# %%
# After training:
# trainer_obj = CodeBERTTrainer(...).run_full_pipeline(output_dir=..., ...)

TEST_PARQUET = "./dataset/test.parquet"  # adjust if needed
OUT_CSV = "submission.csv"

predict_with_trainer(
    trainer_obj=t,          
    parquet_path=TEST_PARQUET,
    output_path=OUT_CSV,
    max_length=256,
    batch_size=32,
    device="cuda"              
)

print("Wrote:", OUT_CSV)
# Out:
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Predicting: 32it [00:06,  4.74it/s]
# Predictions saved to submission.csv
# Wrote: submission.csv

# %%
import torch
from transformers import AutoTokenizer, AutoModel
import torch.nn.functional as F

# Detect device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ALWAYS load the base GraphCodeBERT model (NOT the classifier model!)
tokenizer = AutoTokenizer.from_pretrained("microsoft/graphcodebert-base")
model = AutoModel.from_pretrained("microsoft/graphcodebert-base")

model.to(device)
model.eval()

def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    
    with torch.no_grad():
        outputs = model(**inputs)          # <-- NOW contains last_hidden_state

    cls_emb = outputs.last_hidden_state[:, 0, :]
    return cls_emb.cpu()

def compute_similarity(t1, t2):
    e1 = get_embedding(t1)
    e2 = get_embedding(t2)
    return F.cosine_similarity(e1, e2).item()

# Example
compute_similarity("print('hello')", "print('hello')")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at microsoft/graphcodebert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 1.0
